# %% [markdown]
# Importing libraries

# %%
import matplotlib.pyplot as plt
import cv2 
import os
import numpy as np
# from PIL import Image
import pandas as pd

# %% [markdown]
# Euclidean distance function to calculate the distaance between images

# %%
def euclidean_distance(image, test):
    distance  = np.sqrt ( np.sum( (image-test) ** 2) )
    return distance

# %% [markdown]
# Function that calculates the distances between images and test

# %%
def Image_distances(image1,image2,image3,test):
  
  distance1 = euclidean_distance(image1,test)
  distance2 = euclidean_distance(image2,test)
  distance3 = euclidean_distance(image3,test)
  average_distance = sum(distance1 ,distance2 ,distance3)
  average_distance  = average_distance/3

  return average_distance

# %% [markdown]
# defining cascade function

# %%
# def cascade(img):
#  img = cv2.imread('Photos/cric4.jpg')
  
# # Converting image to grayscale
# gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
# # Loading the required haar-cascade xml classifier file
# haar_cascade = cv2.CascadeClassifier('Haarcascade_frontalface_default.xml')
  
# # Applying the face detection method on the grayscale image
# faces_rect = haar_cascade.detectMultiScale(gray_img, 1.1, 9)
  
# # Iterating through rectangles of detected faces
# for (x, y, w, h) in faces_rect:
#     cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
  
# cv2.imshow('Detected faces', img)
  
# cv2.waitKey(0)

# %% [markdown]
# loading images

# %%
# load the test image and images
test = cv2.imread('leo3.jpg')
image1 = cv2.imread('tom1.jpg')
image2 = cv2.imread('tom2.jpg')
image3 = cv2.imread('tom3.jpg')

# %%
img = cv2.imread('1.jpeg')

pix_arr = np.array(img)
print(pix_arr)
pix_arr.shape
# Out:
# [[[ 97 146 208]
#   [ 96 145 207]
#   [ 92 143 205]
#   ...
#   [219 222 226]
#   [219 222 226]
#   [219 222 226]]
#
#  [[ 98 147 209]
#   [ 96 145 207]
#   [ 93 144 206]
#   ...
#   [219 222 226]
#   [219 222 226]
#   [219 222 226]]
#
#  [[ 98 147 209]
#   [ 97 146 208]
#   [ 94 145 207]
#   ...
#   [219 222 226]
#   [218 221 225]
#   [219 222 226]]
#
#  ...
#
#  [[209 220 228]
#   [209 220 228]
#   [210 221 229]
#   ...
#   [216 223 232]
#   [216 223 232]
#   [216 223 232]]
#
#  [[210 221 229]
#   [210 221 229]
#   [210 221 229]
#   ...
#   [216 223 232]
#   [216 223 232]
#   [216 223 232]]
#
#  [[210 221 229]
#   [211 222 230]
#   [211 222 230]
#   ...
#   [216 223 232]
#   [216 223 232]
#   [216 223 232]]]
# (900, 1600, 3)

# %%
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

faces = face_classifier.detectMultiScale(gray, 1.05, 8)

if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (127,0,255), 2)
    plt.imshow(img)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-109-cfa2f66ba2c1>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
img.shape
image_face = img[y:y+h , x:x+w]
plt.imshow(image_face)

# %%
image2 = cv2.imread('ronaldo.jpeg')

pix_arr = np.array(image2)
print(pix_arr)
pix_arr.shape

face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
image2  = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

faces = face_classifier.detectMultiScale(gray, 1.05, 8)

if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(image2, (x,y), (x+w,y+h), (127,0,255), 2)
    plt.imshow(image2)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()

image2.shape
image2_face = image2[y:y+h , x:x+w]
plt.imshow(image2)
plt.imshow(image2_face)
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# [[[104  91  75]
#   [105  92  76]
#   [105  92  76]
#   ...
#   [121 110  96]
#   [121 110  96]
#   [120 109  95]]
#
#  [[103  90  74]
#   [105  92  76]
#   [105  92  76]
#   ...
#   [121 110  96]
#   [120 109  95]
#   [120 109  95]]
#
#  [[ 98  85  69]
#   [ 99  86  70]
#   [101  88  72]
#   ...
#   [121 110  96]
#   [120 109  95]
#   [120 109  95]]
#
#  ...
#
#  [[112 100  82]
#   [114 102  84]
#   [115 103  85]
#   ...
#   [101  89  71]
#   [102  90  72]
#   [103  91  73]]
#
#  [[112 100  82]
#   [114 102  84]
#   [116 104  86]
#   ...
#   [101  89  71]
#   [102  90  72]
#   [103  91  73]]
#
#  [[112 100  82]
#   [114 102  84]
#   [116 104  86]
#   ...
#   [101  89  71]
#   [102  90  72]
#   [103  91  73]]]
# <ipython-input-151-195bc68ef988>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
image3 = cv2.imread('2.jpeg')

pix_arr = np.array(image3)
print(pix_arr)
pix_arr.shape

face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
gray = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)
image3  = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)

faces = face_classifier.detectMultiScale(gray, 1.05, 8)

if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(image2, (x,y), (x+w,y+h), (127,0,255), 2)
    plt.imshow(image3)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()

image3.shape
image3_face = image3[y:y+h , x:x+w]
plt.imshow(image3)
plt.imshow(image3_face)
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# [[[224 218 213]
#   [218 209 205]
#   [210 201 197]
#   ...
#   [  2  25  70]
#   [  3  25  66]
#   [  3  24  75]]
#
#  [[222 216 211]
#   [215 206 202]
#   [206 197 194]
#   ...
#   [  5  26  78]
#   [  2  24  72]
#   [  3  24  76]]
#
#  [[219 213 206]
#   [212 203 199]
#   [203 194 190]
#   ...
#   [  4  26  78]
#   [  3  26  76]
#   [  3  24  75]]
#
#  ...
#
#  [[ 65  64  66]
#   [ 68  65  67]
#   [ 68  67  71]
#   ...
#   [176 176 176]
#   [176 174 174]
#   [175 175 175]]
#
#  [[ 64  64  64]
#   [ 68  65  67]
#   [ 71  67  72]
#   ...
#   [176 174 174]
#   [174 174 174]
#   [173 173 173]]
#
#  [[ 67  65  71]
#   [ 71  63  73]
#   [ 71  67  73]
#   ...
#   [178 174 173]
#   [176 174 173]
#   [176 174 174]]]
# <ipython-input-112-ab4b79f62274>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
plt.imshow(image_face)
image_face = cv2.resize(image_face,(350,350))
image2_face = cv2.resize(image2_face,(350,350))
image3_face = cv2.resize(image3_face,(350,350))

print(euclidean_distance(image_face,image2_face))
print(euclidean_distance(image_face,image3_face))

# plt.imshow(image2_face)
# plt.imshow(image_face)
# Out:
# 6146.9447695582885
# 6095.910842523864

# %%
image_flat = image_face.flatten()
image2_flat = image2_face.flatten()

image_flat.shape
# Out:
# (367500,)

# %%
plt.imshow(image_face)
image_face.shape
# Out:
# (350, 350, 3)

# %%
gray1 = cv2.cvtColor(image_face, cv2.COLOR_BGR2GRAY)

# %%
gray1.shape
# Out:
# (350, 350)

# %%
gray2 = cv2.cvtColor(image2_face, cv2.COLOR_BGR2GRAY)
gray2.shape
# Out:
# (350, 350)

# %%
euclidean_distance(gray1 , gray2)
# Out:
# 3509.9725070148343

# %%
gray3 = cv2.cvtColor(image3_face, cv2.COLOR_BGR2GRAY)
gray3.shape
# Out:
# (350, 350)

# %%
euclidean_distance(gray1 , gray3)
# Out:
# 3558.6886629768555

# %%
image4 = cv2.imread('tom1.jpg')

pix_arr = np.array(image4)
print(pix_arr)
pix_arr.shape

face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
gray = cv2.cvtColor(image4, cv2.COLOR_BGR2GRAY)
image4  = cv2.cvtColor(image4, cv2.COLOR_BGR2RGB)

faces = face_classifier.detectMultiScale(gray, 1.05, 8)

if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(image4, (x,y), (x+w,y+h), (127,0,255), 2)
    plt.imshow(image4)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()

image4.shape
image4_face = image4[y:y+h , x:x+w]
plt.imshow(image4)
plt.imshow(image4_face)
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# [[[101 127 174]
#   [102 128 175]
#   [104 130 176]
#   ...
#   [102 130 190]
#   [105 133 193]
#   [106 134 194]]
#
#  [[101 127 174]
#   [102 128 175]
#   [103 129 176]
#   ...
#   [102 130 190]
#   [105 133 193]
#   [106 134 194]]
#
#  [[ 99 126 176]
#   [ 99 126 176]
#   [100 127 177]
#   ...
#   [102 130 190]
#   [105 133 193]
#   [106 134 194]]
#
#  ...
#
#  [[ 24  17  20]
#   [ 23  16  19]
#   [ 31  24  27]
#   ...
#   [ 71  59  59]
#   [ 70  58  58]
#   [ 70  58  58]]
#
#  [[ 24  17  20]
#   [ 23  16  19]
#   [ 32  25  28]
#   ...
#   [ 70  58  58]
#   [ 70  58  58]
#   [ 70  58  58]]
#
#  [[ 24  17  20]
#   [ 23  16  19]
#   [ 32  25  28]
#   ...
#   [ 68  56  56]
#   [ 69  57  57]
#   [ 70  58  58]]]
# <ipython-input-129-04362d07e2e3>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
image4_face = cv2.resize(image4_face,(350,350))
image4_flat = image4_face.flatten()

gray4 = cv2.cvtColor(image4_face, cv2.COLOR_BGR2GRAY)
gray4.shape
# Out:
# (350, 350)

# %%
euclidean_distance(gray1 ,gray4)
# Out:
# 3550.937341041095

# %%
d = euclidean_distance(gray1,gray2)
if d < 3500:
  print("Same Person")
else: 
  print("Not the same person")
# Out:
# Not the same person

# %%
# # img is our input image represented by a numpy array
# pixel_list = lin_img.tolist()
# pixel_str_list = map(str, pixel_list)
# img_str = ' '.join(pixel_str_list)

# %%
# print(lin_img)
# df = pd.DataFrame(lin_img)
# df.head()
# lin_img.shape
# Out:
# [10 11  7 ... 13 13 13]
# (50700000,)

# %%
# pix_arr.shape
# print(5000*3380*3)
# Out:
# 50700000
